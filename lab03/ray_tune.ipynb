# %% [markdown]
# # Hyperparameter tuning with Ray Tune
#
# [Ray Tune](https://docs.ray.io/en/latest/tune/index.html) is a library for experiment execution and hyperparameter tuning at any scale. It supports most machine learning frameworks, a variety of state-of-the-art algorithms, and integrates a wide range of dedicated hyperparameter optimization tools.
#
# ## Key Concepts
#
# There are [six concepts to understand](https://docs.ray.io/en/latest/tune/key-concepts.html):
#
# 1. Search Spaces: A search space defines the set of valid parameters for your hyperparameters.
# 2. Trainable: In Tune, the objective you want to minimize/maximize is represented by a [Trainable](https://docs.ray.io/en/latest/tune/key-concepts.html#ray-tune-trainables). Trainables are [functions](https://docs.ray.io/en/latest/tune/api/trainable.html#tune-function-api) or [classes](https://docs.ray.io/en/latest/tune/api/trainable.html#class-trainable-api) that take hyperparameters as input and return metric.
# 3. Search Algorithms: Search algorithms do the heavy lifting, as they describe _how_ to tune the Trainable.
# 4. Schedulers: Tune can optionally use a Scheduler to stop searches early and thus speed up the hyperparameter search process.
# 5. Trials: Trials are a concrete combination of hyperparameter values.
# 6. Analyses: After the search process has terminated, Tune will present you with a `ResultGrid`, which allows you to access various metrics such as the best available trial or the hyperparameter configuration for said trial.
#
# ![Tune Flow](imgs/tune_flow.png)
#
# Image taken from the [tune documentation](https://docs.ray.io/en/latest/tune/key-concepts.html).
#
# With these concepts in mind, we can create a blueprint for any Tune script:

# %%
from ray import tune, train


def trainable(config):
    # config is a dict containing the hyperparameters, it is a sample from the search space
    
    # train your model using the hyperparameters
    # ...
    score = 0.5

    # return the score
    return {"score": score}


# Define the search space
search_space = {
    # Your hyperparameters go here
}

# Select the search algorithm and its parameters
# (e.g. Random Search, Bayesian Optimization, HyperBand, etc.; Searcher is the base class for all search algorithms)
algo = tune.search.Searcher(
    # Your search algorithm parameters go here
)

# Select the scheduler and its parameters
# (e.g. HyperBand, ASHAScheduler, etc.; Scheduler is the base class for all schedulers)
scheduler = tune.schedulers.TrialScheduler(
    # Your scheduler parameters go here
)

# Define the tune_config
tune_config = tune.TuneConfig(
    # Name of the metric that the trainable returns
    # and we want to optimize.
    metric="score",
    # The mode can be "min" or "max"
    mode="max",
    # The search algorithm
    search_alg=algo,
    # The scheduler
    scheduler=scheduler,
    # Number of times to sample from the hyperparameter space
    num_samples=10,
)

# Define the run_config.
run_config = train.RunConfig(stop={"training_iteration": 20})

tuner = tune.Tuner(
    trainable=trainable,
    tune_config=tune_config,
    run_config=run_config,
    param_space=search_space,
)

# Start the search
results = tuner.fit() # returns result grid

# %% [markdown]
# This is of course very abstract. Let's look at a concrete example: grid search.
#
# ### Grid Search with Ray Tune
#
# In this example, we will be trying to minimize the following objective:
#
# ```python
# def trainable(config):
#     # Hyperparameters
#     width, height, activation = config["width"], config["height"], config["activation"]
#     for step in range(config["steps"]):
#         loss = loss_fn(step, width, height, activation)
#         train.report({"iterations": step, "mean_loss": loss})
# ```
#
# with the loss function `loss_fn` defined as
#
# ```python
# def loss_fn(step, width, height, activation):
#     pre_act = (0.1 + width * step / 100) ** (-1) + height * 0.1
#     if 'relu' == activation:
#         return F.relu(pre_act)
#     elif 'tanh' == activation:
#         return F.sigmoid(pre_act)
# ```
#
# Grid / random search (implemented by the [`BasicVariantGenerator`](https://docs.ray.io/en/latest/tune/api/doc/ray.tune.search.basic_variant.BasicVariantGenerator.html#ray.tune.search.basic_variant.BasicVariantGenerator)) is the default search algorithm in Ray Tune, it is selected automatically when no search algorithm is passed to the `Tuner`. You can find the complete list of search algorithms [in the docs](https://docs.ray.io/en/latest/tune/api/suggestion.html#random-search-and-grid-search-tune-search-basic-variant-basicvariantgenerator).
#
# We will perform a grid search over the `activation`. This means that, for each value, either `relu` or `sigmoid`, we'll randomly sample an equal amount of values for `width`, `height`.
#
# Our search space looks as follows:
#
# ```python
#     search_space={
#         "steps": 100,  # We don't want to optimize the number of steps.
#         "width": tune.uniform(0, 20),
#         "height": tune.uniform(-100, 100),
#         "activation": tune.grid_search(["relu", "tanh"]),
#     }
# ```
#
# `tune.uniform` describes a uniform distribution. `tune.grid_search` guarantees that the values are sampled `num_samples` times (`num_samples` is a parameter of [`TunerConfig`](https://docs.ray.io/en/latest/tune/api/doc/ray.tune.TuneConfig.html#ray.tune.TuneConfig), see the blueprint above). For a full list of the random distributions supported by the search space API, refer to the [corresponding page in the documentation](https://docs.ray.io/en/latest/tune/api/search_space.html#tune-search-space-api).
#
# The trainable, search algorithm, and search space are everything we need. Let's add them to the blueprint.

# %%
from ray import tune, train
import torch
import torch.nn.functional as F

def loss_fn(step, width, height, activation):
    pre_act = torch.tensor((0.1 + width * step / 100) ** (-1) + height * 0.1)
    if "relu" == activation:
        return F.relu(pre_act)
    elif "tanh" == activation:
        return F.tanh(pre_act)

def trainable(config):
    # Hyperparameters
    width, height, activation = config["width"], config["height"], config["activation"]

    for step in range(config["steps"]):
        loss = loss_fn(step, width, height, activation)
        train.report({"iterations": step, "mean_loss": loss.item()})


# Define the search space
search_space = {
    "steps": 100,
    "width": tune.uniform(0, 20),
    "height": tune.uniform(-100, 100),
    "activation": tune.grid_search(["relu", "tanh"]),
}

# Select the search algorithm and its parameters
algo = tune.search.basic_variant.BasicVariantGenerator()

# We're not using a scheduler in this example
scheduler = None

# Define the tune_config
tune_config = tune.TuneConfig(
    metric="mean_loss",
    mode="min",
    search_alg=algo,
    scheduler=scheduler,
    num_samples=50,
)

# Define the run_config.
run_config = train.RunConfig(name="Grid search experiment")

tuner = tune.Tuner(
    trainable=trainable,
    tune_config=tune_config,
    run_config=run_config,
    param_space=search_space,
)

# Start the search
results = tuner.fit()  # returns result grid
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-03-18 14:11:22</td></tr>
# <tr><td>Running for: </td><td>00:01:03.71        </td></tr>
# <tr><td>Memory:      </td><td>8.6/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc           </th><th>activation  </th><th style="text-align: right;">   height</th><th style="text-align: right;">    width</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_548b9_00000</td><td>TERMINATED</td><td>127.0.0.1:3994</td><td>relu        </td><td style="text-align: right;">-22.9221 </td><td style="text-align: right;"> 8.41859 </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0107439 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00001</td><td>TERMINATED</td><td>127.0.0.1:3998</td><td>tanh        </td><td style="text-align: right;">-73.3395 </td><td style="text-align: right;"> 2.9791  </td><td style="text-align: right;">-0.999998</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0131283 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00002</td><td>TERMINATED</td><td>127.0.0.1:3997</td><td>relu        </td><td style="text-align: right;">-73.2647 </td><td style="text-align: right;">15.1497  </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0156734 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00003</td><td>TERMINATED</td><td>127.0.0.1:3999</td><td>tanh        </td><td style="text-align: right;">-19.7836 </td><td style="text-align: right;">17.0463  </td><td style="text-align: right;">-0.957872</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00978827</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00004</td><td>TERMINATED</td><td>127.0.0.1:3995</td><td>relu        </td><td style="text-align: right;">-98.0011 </td><td style="text-align: right;">18.9521  </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0171704 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00005</td><td>TERMINATED</td><td>127.0.0.1:3992</td><td>tanh        </td><td style="text-align: right;">-54.3481 </td><td style="text-align: right;">15.8323  </td><td style="text-align: right;">-0.999957</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.010165  </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00006</td><td>TERMINATED</td><td>127.0.0.1:3996</td><td>relu        </td><td style="text-align: right;"> -2.75463</td><td style="text-align: right;"> 3.68036 </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0134754 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00007</td><td>TERMINATED</td><td>127.0.0.1:3993</td><td>tanh        </td><td style="text-align: right;">-54.1314 </td><td style="text-align: right;">16.4875  </td><td style="text-align: right;">-0.999955</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0200071 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00008</td><td>TERMINATED</td><td>127.0.0.1:4023</td><td>relu        </td><td style="text-align: right;">-74.6032 </td><td style="text-align: right;">18.8045  </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0080533 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00009</td><td>TERMINATED</td><td>127.0.0.1:4025</td><td>tanh        </td><td style="text-align: right;">-13.7424 </td><td style="text-align: right;">17.488   </td><td style="text-align: right;">-0.865988</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00903535</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00010</td><td>TERMINATED</td><td>127.0.0.1:4024</td><td>relu        </td><td style="text-align: right;">  6.63066</td><td style="text-align: right;">12.8585  </td><td style="text-align: right;"> 0.74101 </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00881124</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00011</td><td>TERMINATED</td><td>127.0.0.1:4028</td><td>tanh        </td><td style="text-align: right;"> 89.4185 </td><td style="text-align: right;">17.8333  </td><td style="text-align: right;"> 1       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00899625</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00012</td><td>TERMINATED</td><td>127.0.0.1:4030</td><td>relu        </td><td style="text-align: right;">-37.0707 </td><td style="text-align: right;"> 5.28387 </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00850558</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00013</td><td>TERMINATED</td><td>127.0.0.1:4029</td><td>tanh        </td><td style="text-align: right;"> 15.5798 </td><td style="text-align: right;">10.9708  </td><td style="text-align: right;"> 0.928749</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00836229</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00014</td><td>TERMINATED</td><td>127.0.0.1:4027</td><td>relu        </td><td style="text-align: right;"> 71.9443 </td><td style="text-align: right;"> 1.50772 </td><td style="text-align: right;"> 7.82232 </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00892138</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00015</td><td>TERMINATED</td><td>127.0.0.1:4026</td><td>tanh        </td><td style="text-align: right;">  3.28258</td><td style="text-align: right;">12.1448  </td><td style="text-align: right;"> 0.389104</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00864053</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00016</td><td>TERMINATED</td><td>127.0.0.1:4073</td><td>relu        </td><td style="text-align: right;"> 60.0509 </td><td style="text-align: right;"> 9.14215 </td><td style="text-align: right;"> 6.11437 </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0100729 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00017</td><td>TERMINATED</td><td>127.0.0.1:4071</td><td>tanh        </td><td style="text-align: right;">-47.5243 </td><td style="text-align: right;">19.3453  </td><td style="text-align: right;">-0.999835</td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00869417</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_548b9_00018</td><td>TERMINATED</td><td>127.0.0.1:4
# 2025-03-18 14:11:22,987	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/jaron/ray_results/Grid search experiment' in 0.0481s.
# 2025-03-18 14:11:22,997	INFO tune.py:1041 -- Total run time: 63.78 seconds (63.66 seconds for the tuning loop).

# %% [markdown]
# You can access the best run via `ResultGrid.get_best_result()`...

# %%
results.get_best_result()
# Out:
# Result(
#   metrics={'iterations': 99, 'mean_loss': -1.0},
#   path='/Users/jaron/ray_results/Grid search experiment/trainable_548b9_00043_43_activation=tanh,height=-96.9614,width=13.9640_2025-03-18_14-10-19',
#   filesystem='local',
#   checkpoint=None
# )

# %% [markdown]
# ... and the corresponding configuration:

# %%
results.get_best_result().config
# Out:
# {'steps': 100,
#  'width': 13.964045786388974,
#  'height': -96.96137793658775,
#  'activation': 'tanh'}

# %% [markdown]
# ### Walking on egg shells
#
# Now it's your turn. Use the blueprint above to optimize the following function:
#
# $$
# f(x, y) = -(y + 47) \cdot \sin\left(\sqrt{\left| \frac{x}{2} + (y + 47) \right|}\right) - x \cdot \sin\left(\sqrt{\left| x - (y + 47) \right|}\right)
# $$
#
# also known as the Eggholder function. The search domain is $-512 \leq x, y \leq 512$.
#
# Implement the function as a trainable and find $(x, y)$ which minimize the eggholder. Use the [`HEBOSearch`](https://docs.ray.io/en/latest/tune/api/doc/ray.tune.search.hebo.HEBOSearch.html#ray.tune.search.hebo.HEBOSearch) search algorithm.
#
# _Note: One could of course use a gradient-based optimizer to minimize this function - but that's not the point here. ;)_

# %%
# Your code goes here.
from ray.tune.search.hebo import HEBOSearch

def loss_eh(x, y):
    pre_act = -(y + 47) * torch.sin(torch.sqrt(torch.abs((x / 2) + (y + 47)))) - x * torch.sin(torch.sqrt(torch.abs(x - (y + 47))))
    return F.relu(pre_act)

def trainable(config):
    # Hyperparameters
    x = torch.tensor(config["x"], dtype=torch.float32)
    y = torch.tensor(config["y"], dtype=torch.float32)

    for step in range(config["steps"]):
        loss = loss_eh(x, y)
        train.report({"iterations": step, "mean_loss": loss.item()})

# Define the search space
search_space = {
    "steps": 100,
    "x": tune.uniform(-512, 512),
    "y": tune.uniform(-512, 512)
}

# Select the search algorithm and its parameters
algo = HEBOSearch()

# We're not using a scheduler in this example
scheduler = None

# Define the tune_config
tune_config = tune.TuneConfig(
    metric="mean_loss",
    mode="min",
    search_alg=algo,
    scheduler=scheduler,
    num_samples=50,
)

# Define the run_config.
run_config = train.RunConfig(name="Grid search experiment")

tuner = tune.Tuner(
    trainable=trainable,
    tune_config=tune_config,
    run_config=run_config,
    param_space=search_space,
)

# Start the search
results = tuner.fit()  # returns result grid
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-03-18 14:26:07</td></tr>
# <tr><td>Running for: </td><td>00:01:40.69        </td></tr>
# <tr><td>Memory:      </td><td>9.6/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc           </th><th style="text-align: right;">         x</th><th style="text-align: right;">         y</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_636b0c88</td><td>TERMINATED</td><td>127.0.0.1:7774</td><td style="text-align: right;">  91.0682 </td><td style="text-align: right;">-236.863  </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.010184  </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_f40944a3</td><td>TERMINATED</td><td>127.0.0.1:7784</td><td style="text-align: right;">-177.758  </td><td style="text-align: right;">  47.8817 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00939822</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_301615a1</td><td>TERMINATED</td><td>127.0.0.1:7791</td><td style="text-align: right;">-432.637  </td><td style="text-align: right;">-284.029  </td><td style="text-align: right;">580.256  </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00973058</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_23509142</td><td>TERMINATED</td><td>127.0.0.1:7798</td><td style="text-align: right;"> 346.439  </td><td style="text-align: right;"> 479.234  </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00901937</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_686d23ba</td><td>TERMINATED</td><td>127.0.0.1:7805</td><td style="text-align: right;"> 408.288  </td><td style="text-align: right;">-439.591  </td><td style="text-align: right;">370.519  </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00931358</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_1c59d2dd</td><td>TERMINATED</td><td>127.0.0.1:7812</td><td style="text-align: right;">-370.605  </td><td style="text-align: right;"> 372.672  </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00937033</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_16085da3</td><td>TERMINATED</td><td>127.0.0.1:7831</td><td style="text-align: right;">-115.984  </td><td style="text-align: right;"> -71.3011 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00910473</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_a78ad782</td><td>TERMINATED</td><td>127.0.0.1:7859</td><td style="text-align: right;"> 153.158  </td><td style="text-align: right;"> 132.444  </td><td style="text-align: right;">191.971  </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00977445</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_20cf6756</td><td>TERMINATED</td><td>127.0.0.1:7878</td><td style="text-align: right;">-127.663  </td><td style="text-align: right;"> -51.5655 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0106044 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_ed49182a</td><td>TERMINATED</td><td>127.0.0.1:7885</td><td style="text-align: right;">-122.319  </td><td style="text-align: right;">  -1.47109</td><td style="text-align: right;"> 79.4556 </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0095377 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_ac87f7f6</td><td>TERMINATED</td><td>127.0.0.1:7998</td><td style="text-align: right;">  50.3387 </td><td style="text-align: right;">  10.2363 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00970411</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_7d003fa9</td><td>TERMINATED</td><td>127.0.0.1:8096</td><td style="text-align: right;"> 135.729  </td><td style="text-align: right;"> -15.0113 </td><td style="text-align: right;">110.762  </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00896835</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_54b71081</td><td>TERMINATED</td><td>127.0.0.1:8110</td><td style="text-align: right;">  49.9908 </td><td style="text-align: right;">-139.314  </td><td style="text-align: right;">116.434  </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00915122</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_72de8541</td><td>TERMINATED</td><td>127.0.0.1:8123</td><td style="text-align: right;"> -96.3832 </td><td style="text-align: right;">  -6.10414</td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00931835</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_df392156</td><td>TERMINATED</td><td>127.0.0.1:8130</td><td style="text-align: right;">   8.64949</td><td style="text-align: right;"> 121.73   </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00984788</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_b7f0b69d</td><td>TERMINATED</td><td>127.0.0.1:8142</td><td style="text-align: right;">-103.698  </td><td style="text-align: right;"> -18.0303 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.0102322 </td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_25e10098</td><td>TERMINATED</td><td>127.0.0.1:8154</td><td style="text-align: right;"> -25.3525 </td><td style="text-align: right;">  -1.63627</td><td style="text-align: right;"> 45.8655 </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00891185</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_a95004da</td><td>TERMINATED</td><td>127.0.0.1:8161</td><td style="text-align: right;"> -59.9914 </td><td style="text-align: right;"> -13.914  </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00898719</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_a8461332</td><td>TERMINATED</td><td>127.0.0.1:8168</td><td style="text-align: right;"> -77.1961 </td><td style="text-align: right;"> -18.0559 </td><td style="text-align: right;">  0      </td><td style="text-align: right;">   100</td><td style="text-align: right;">      0.00918293</td><td style="text-align: right;">          99</td></tr>
# <tr><td>trainable_f29b288c</td><td>TERMINATED</td><td>127.0.0.1:8175</td><td style="text-align: right;"> -79.269  </td><td style
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
# 2025-03-18 14:26:07,677	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/jaron/ray_results/Grid search experiment' in 0.0446s.
# 2025-03-18 14:26:07,683	INFO tune.py:1041 -- Total run time: 100.71 seconds (100.65 seconds for the tuning loop).

# %%
results.get_best_result()
# Out:
# Result(
#   metrics={'iterations': 99, 'mean_loss': 0.0},
#   path='/Users/jaron/ray_results/Grid search experiment/trainable_636b0c88_1_steps=100,x=91.0682,y=-236.8633_2025-03-18_14-24-26',
#   filesystem='local',
#   checkpoint=None
# )

# %%
results.get_best_result().config
# Out:
# {'steps': 100, 'x': 91.0682373046875, 'y': -236.86331176757812}

# %% [markdown]
# ## Tracking hyperparameter experiments
#
# Ray Tune integrates with a range of experiment tracking tools, including MLflow. To integrate MLflow (or any tracking framework for that matter), there are two options.
#
# 1. the Callback API
# 2. the `setup_<integration>` function
#
# The callback API is easier to set up but gives you slightly less control over what is logged to MLflow than `setup_mlflow`.
# We'll only show how to use the callback API, but you are of course invited to explore the `setup_*` option on your own.
#
# Using the callback API is as easy as adding the callback to the `RunConfig`.

# %%
from ray.air.integrations.mlflow import MLflowLoggerCallback

run_config_with_callback = train.RunConfig(
    name="MLFlow logging experiment",
    callbacks=[MLflowLoggerCallback(
        tracking_uri="http://localhost:8080",  # Replace with your MLFlow tracking server URI.
        experiment_name="ray-tune-experiments",
        save_artifact=True
    )],
)

# %% [markdown]
# Everything else is the same as before!

# %%
def loss_fn(step, width, height, activation):
    pre_act = torch.tensor((0.1 + width * step / 100) ** (-1) + height * 0.1)
    if "relu" == activation:
        return F.relu(pre_act)
    elif "tanh" == activation:
        return F.tanh(pre_act)

def trainable(config):
    # Hyperparameters
    width, height, activation = config["width"], config["height"], config["activation"]

    for step in range(config["steps"]):
        loss = loss_fn(step, width, height, activation)
        train.report({"iterations": step, "mean_loss": loss.item()})


# Define the search space
search_space = {
    "steps": 100,
    "width": tune.uniform(0, 20),
    "height": tune.uniform(-100, 100),
    "activation": tune.grid_search(["relu", "tanh"]),
}

# Select the search algorithm and its parameters
algo = tune.search.basic_variant.BasicVariantGenerator()

# We're not using a scheduler in this example
scheduler = None

# Define the tune_config
tune_config = tune.TuneConfig(
    metric="mean_loss",
    mode="min",
    search_alg=algo,
    scheduler=scheduler,
    num_samples=50,
)

tuner = tune.Tuner(
    trainable=trainable,
    tune_config=tune_config,
    run_config=run_config_with_callback,
    param_space=search_space,
)

# Start the search
results = tuner.fit()  # returns result grid
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-03-18 14:34:22</td></tr>
# <tr><td>Running for: </td><td>00:05:47.13        </td></tr>
# <tr><td>Memory:      </td><td>10.7/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">    height</th><th style="text-align: right;">      width</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_e4f20_00032</td><td>RUNNING   </td><td>127.0.0.1:9918 </td><td>relu        </td><td style="text-align: right;">-36.1854  </td><td style="text-align: right;">13.5531    </td><td style="text-align: right;"> 0       </td><td style="text-align: right;">    61</td><td style="text-align: right;">      0.0132766 </td><td style="text-align: right;">          60</td></tr>
# <tr><td>trainable_e4f20_00033</td><td>RUNNING   </td><td>127.0.0.1:9950 </td><td>tanh        </td><td style="text-align: right;"> 11.1998  </td><td style="text-align: right;">19.0929    </td><td style="text-align: right;"> 0.838483</td><td style="text-align: right;">    55</td><td style="text-align: right;">      0.0121045 </td><td style="text-align: right;">          54</td></tr>
# <tr><td>trainable_e4f20_00034</td><td>RUNNING   </td><td>127.0.0.1:9958 </td><td>relu        </td><td style="text-align: right;">  1.92628 </td><td style="text-align: right;"> 2.10904   </td><td style="text-align: right;"> 1.18579 </td><td style="text-align: right;">    44</td><td style="text-align: right;">      0.0109074 </td><td style="text-align: right;">          43</td></tr>
# <tr><td>trainable_e4f20_00035</td><td>RUNNING   </td><td>127.0.0.1:9977 </td><td>tanh        </td><td style="text-align: right;"> 64.7402  </td><td style="text-align: right;">16.9547    </td><td style="text-align: right;"> 0.999996</td><td style="text-align: right;">    50</td><td style="text-align: right;">      0.0107286 </td><td style="text-align: right;">          49</td></tr>
# <tr><td>trainable_e4f20_00036</td><td>RUNNING   </td><td>127.0.0.1:9991 </td><td>relu        </td><td style="text-align: right;"> 82.7227  </td><td style="text-align: right;">11.6517    </td><td style="text-align: right;"> 8.47252 </td><td style="text-align: right;">    43</td><td style="text-align: right;">      0.00889397</td><td style="text-align: right;">          42</td></tr>
# <tr><td>trainable_e4f20_00037</td><td>RUNNING   </td><td>127.0.0.1:10000</td><td>tanh        </td><td style="text-align: right;"> 41.3346  </td><td style="text-align: right;"> 7.53196   </td><td style="text-align: right;"> 0.999726</td><td style="text-align: right;">    42</td><td style="text-align: right;">      0.00933838</td><td style="text-align: right;">          41</td></tr>
# <tr><td>trainable_e4f20_00038</td><td>RUNNING   </td><td>127.0.0.1:10001</td><td>relu        </td><td style="text-align: right;"> 84.9256  </td><td style="text-align: right;">12.0189    </td><td style="text-align: right;"> 8.75393 </td><td style="text-align: right;">    32</td><td style="text-align: right;">      0.00770497</td><td style="text-align: right;">          31</td></tr>
# <tr><td>trainable_e4f20_00039</td><td>RUNNING   </td><td>127.0.0.1:10033</td><td>tanh        </td><td style="text-align: right;"> 64.5812  </td><td style="text-align: right;"> 0.759428  </td><td style="text-align: right;"> 1       </td><td style="text-align: right;">    19</td><td style="text-align: right;">      0.00541234</td><td style="text-align: right;">          18</td></tr>
# <tr><td>trainable_e4f20_00040</td><td>PENDING   </td><td>               </td><td>relu        </td><td style="text-align: right;">-97.1368  </td><td style="text-align: right;">13.8461    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00041</td><td>PENDING   </td><td>               </td><td>tanh        </td><td style="text-align: right;">-27.0868  </td><td style="text-align: right;"> 3.6085    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00042</td><td>PENDING   </td><td>               </td><td>relu        </td><td style="text-align: right;"> 17.3639  </td><td style="text-align: right;"> 9.73199   </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00043</td><td>PENDING   </td><td>               </td><td>tanh        </td><td style="text-align: right;">-12.6763  </td><td style="text-align: right;"> 9.82497   </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00044</td><td>PENDING   </td><td>               </td><td>relu        </td><td style="text-align: right;">-90.9778  </td><td style="text-align: right;">10.3074    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00045</td><td>PENDING   </td><td>               </td><td>tanh        </td><td style="text-align: right;">  7.4803  </td><td style="text-align: right;"> 4.6475    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00046</td><td>PENDING   </td><td>               </td><td>relu        </td><td style="text-align: right;">-10.5228  </td><td style="text-align: right;">10.0259    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00047</td><td>PENDING   </td><td>               </td><td>tanh        </td><td style="text-align: right;"> 46.1854  </td><td style="text-align: right;">14.1627    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00048</td><td>PENDING   </td><td>               </td><td>relu        </td><td style="text-align: right;"> -6.8985  </td><td style="text-align: right;">19.8998    </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </td></tr>
# <tr><td>trainable_e4f20_00049</td><td>PENDING   </td><td>               </td><td>tanh        </td><td style="text-align: right;">-53.7695  </td><td style="text-align: right;"> 2.26366   </td><td style="text-align: right;">         </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">            </t
# 🏃 View run trainable_e4f20_00002 at: http://localhost:8080/#/experiments/429530962525741147/runs/83d9088166ff4804b023f2e1fb7bd319
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00000 at: http://localhost:8080/#/experiments/429530962525741147/runs/891a2c7911574897a32f682f9473913e
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00001 at: http://localhost:8080/#/experiments/429530962525741147/runs/d7e75a09a61244f2877631fcfce6f2ce
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00007 at: http://localhost:8080/#/experiments/429530962525741147/runs/0a192d6e3f4b4ccea1206fa9e89ce1d3
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00006 at: http://localhost:8080/#/experiments/429530962525741147/runs/cf8c554f1aa344e598e303c170dd7509
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00005 at: http://localhost:8080/#/experiments/429530962525741147/runs/47c2f1b8ad974886a5d3de66e925688c
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00003 at: http://localhost:8080/#/experiments/429530962525741147/runs/32be68fd4cb64e83be2ca5887d40f2a4
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00004 at: http://localhost:8080/#/experiments/429530962525741147/runs/30d49c1a387c4ffa9f3edb9c7fb4f85e
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00013 at: http://localhost:8080/#/experiments/429530962525741147/runs/c9aa3590a7204adfa6a91d8449476394
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00008 at: http://localhost:8080/#/experiments/429530962525741147/runs/d303e646316a49b38976bc58864b67b9
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00014 at: http://localhost:8080/#/experiments/429530962525741147/runs/1faf0ba0782846bcbd5c459b7a6f4799
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00009 at: http://localhost:8080/#/experiments/429530962525741147/runs/ce55d73d766c4573ac7b61e1bfc85dc8
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00010 at: http://localhost:8080/#/experiments/429530962525741147/runs/b5c692be17b14deba720649c11b76b48
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00011 at: http://localhost:8080/#/experiments/429530962525741147/runs/7e497b0fe7df42f3bc62c7af059441b2
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00015 at: http://localhost:8080/#/experiments/429530962525741147/runs/eda7d76154224607974a14cac4e373f8
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00012 at: http://localhost:8080/#/experiments/429530962525741147/runs/42699202d32c4c00a92d323491890e41
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00020 at: http://localhost:8080/#/experiments/429530962525741147/runs/4f18d37c083d42f9ada311ae39dce1b1
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00018 at: http://localhost:8080/#/experiments/429530962525741147/runs/9955179dc95640eeb697fa743890a7fd
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00016 at: http://localhost:8080/#/experiments/429530962525741147/runs/48860a27bb0747fda6c7254f8fc182ce
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00019 at: http://localhost:8080/#/experiments/429530962525741147/runs/13e0caddf02e437293a567b9bfae8dc8
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00021 at: http://localhost:8080/#/experiments/429530962525741147/runs/4009740ca8d74174b6ffcef0828e4ece
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00017 at: http://localhost:8080/#/experiments/429530962525741147/runs/e6c7d2ac903b49c196c9f35266f6e88f
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00023 at: http://localhost:8080/#/experiments/429530962525741147/runs/181994906fde4cf39713302341e12d1c
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00022 at: http://localhost:8080/#/experiments/429530962525741147/runs/5e2277a6b05e4c2da32e2dc821b98255
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00026 at: http://localhost:8080/#/experiments/429530962525741147/runs/f63e3b0f13fc43fe9afd6416b9950619
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00024 at: http://localhost:8080/#/experiments/429530962525741147/runs/b229cf28ba7f408ea4e589f73f307aff
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00027 at: http://localhost:8080/#/experiments/429530962525741147/runs/dfed45eb8b6842da9a633931cadcc911
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00025 at: http://localhost:8080/#/experiments/429530962525741147/runs/37af8665b4a24312bba0c3781e1bf79a
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00028 at: http://localhost:8080/#/experiments/429530962525741147/runs/411891c401a14131b2a1a66cd41d1462
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00030 at: http://localhost:8080/#/experiments/429530962525741147/runs/10ab1287e19a4eb9a51a08585b26a216
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00029 at: http://localhost:8080/#/experiments/429530962525741147/runs/085673c9db6045648344dd4e1e6e0dc9
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 🏃 View run trainable_e4f20_00031 at: http://localhost:8080/#/experiments/429530962525741147/runs/4a4becdb8d3542238205d796f32e0592
# 🧪 View experiment at: http://localhost:8080/#/experiments/429530962525741147
# 2025-03-18 14:34:22,713	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2025-03-18 14:34:22,856	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/jaron/ray_results/MLFlow logging experiment' in 0.0388s.
# 2025-03-18 14:34:22,910	INFO tune.py:1041 -- Total run time: 347.28 seconds (347.09 seconds for the tuning loop).
# 2025-03-18 14:34:22,913	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/Users/jaron/ray_results/MLFlow logging experiment", trainable=...)
# 2025-03-18 14:34:23,047	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 60 trial(s):
# - trainable_e4f20_00040: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00040: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00040_40_activation=relu,height=-97.1368,width=13.8461_2025-03-18_14-28-35')
# - trainable_e4f20_00041: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00041: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00041_41_activation=tanh,height=-27.0868,width=3.6085_2025-03-18_14-28-35')
# - trainable_e4f20_00042: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00042: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00042_42_activation=relu,height=17.3639,width=9.7320_2025-03-18_14-28-35')
# - trainable_e4f20_00043: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00043: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00043_43_activation=tanh,height=-12.6763,width=9.8250_2025-03-18_14-28-35')
# - trainable_e4f20_00044: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00044: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00044_44_activation=relu,height=-90.9778,width=10.3074_2025-03-18_14-28-35')
# - trainable_e4f20_00045: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00045: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00045_45_activation=tanh,height=7.4803,width=4.6475_2025-03-18_14-28-35')
# - trainable_e4f20_00046: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00046: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00046_46_activation=relu,height=-10.5228,width=10.0259_2025-03-18_14-28-35')
# - trainable_e4f20_00047: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00047: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00047_47_activation=tanh,height=46.1854,width=14.1627_2025-03-18_14-28-35')
# - trainable_e4f20_00048: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00048: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00048_48_activation=relu,height=-6.8985,width=19.8998_2025-03-18_14-28-35')
# - trainable_e4f20_00049: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00049: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00049_49_activation=tanh,height=-53.7695,width=2.2637_2025-03-18_14-28-35')
# - trainable_e4f20_00050: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00050: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00050_50_activation=relu,height=-48.3324,width=1.3362_2025-03-18_14-28-35')
# - trainable_e4f20_00051: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00051: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00051_51_activation=tanh,height=-95.0733,width=17.4868_2025-03-18_14-28-35')
# - trainable_e4f20_00052: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00052: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00052_52_activation=relu,height=19.4891,width=5.2296_2025-03-18_14-28-35')
# - trainable_e4f20_00053: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00053: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00053_53_activation=tanh,height=8.7569,width=16.8466_2025-03-18_14-28-35')
# - trainable_e4f20_00054: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00054: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00054_54_activation=relu,height=15.1673,width=16.3855_2025-03-18_14-28-35')
# - trainable_e4f20_00055: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00055: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00055_55_activation=tanh,height=-48.7327,width=1.9876_2025-03-18_14-28-35')
# - trainable_e4f20_00056: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00056: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00056_56_activation=relu,height=0.1006,width=16.0921_2025-03-18_14-28-35')
# - trainable_e4f20_00057: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00057: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00057_57_activation=tanh,height=28.8577,width=9.9383_2025-03-18_14-28-35')
# - trainable_e4f20_00058: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00058: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00058_58_activation=relu,height=-7.9181,width=9.2072_2025-03-18_14-28-35')
# - trainable_e4f20_00059: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00059: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00059_59_activation=tanh,height=-7.4153,width=14.5018_2025-03-18_14-28-35')
# - trainable_e4f20_00060: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00060: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00060_60_activation=relu,height=-75.0395,width=15.6761_2025-03-18_14-28-35')
# - trainable_e4f20_00061: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00061: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00061_61_activation=tanh,height=93.2116,width=15.6042_2025-03-18_14-28-35')
# - trainable_e4f20_00062: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00062: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00062_62_activation=relu,height=95.4675,width=15.7151_2025-03-18_14-28-35')
# - trainable_e4f20_00063: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00063: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00063_63_activation=tanh,height=77.5173,width=13.1129_2025-03-18_14-28-35')
# - trainable_e4f20_00064: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00064: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00064_64_activation=relu,height=-14.7718,width=15.8078_2025-03-18_14-28-35')
# - trainable_e4f20_00065: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00065: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00065_65_activation=tanh,height=65.1232,width=12.1895_2025-03-18_14-28-35')
# - trainable_e4f20_00066: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00066: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00066_66_activation=relu,height=-86.1380,width=7.4555_2025-03-18_14-28-35')
# - trainable_e4f20_00067: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00067: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00067_67_activation=tanh,height=46.1908,width=16.9909_2025-03-18_14-28-35')
# - trainable_e4f20_00068: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00068: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00068_68_activation=relu,height=43.3679,width=12.5778_2025-03-18_14-28-35')
# - trainable_e4f20_00069: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00069: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00069_69_activation=tanh,height=13.3531,width=1.5150_2025-03-18_14-28-35')
# - trainable_e4f20_00070: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00070: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00070_70_activation=relu,height=13.3160,width=18.3329_2025-03-18_14-28-35')
# - trainable_e4f20_00071: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00071: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00071_71_activation=tanh,height=-73.2838,width=6.4859_2025-03-18_14-28-35')
# - trainable_e4f20_00072: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00072: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00072_72_activation=relu,height=-17.0901,width=11.3368_2025-03-18_14-28-35')
# - trainable_e4f20_00073: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00073: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00073_73_activation=tanh,height=-48.4509,width=4.5683_2025-03-18_14-28-35')
# - trainable_e4f20_00074: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00074: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00074_74_activation=relu,height=-24.7743,width=17.6848_2025-03-18_14-28-35')
# - trainable_e4f20_00075: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00075: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00075_75_activation=tanh,height=19.8477,width=0.0038_2025-03-18_14-28-35')
# - trainable_e4f20_00076: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00076: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00076_76_activation=relu,height=-26.8920,width=13.6152_2025-03-18_14-28-35')
# - trainable_e4f20_00077: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00077: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00077_77_activation=tanh,height=-57.0711,width=12.4241_2025-03-18_14-28-35')
# - trainable_e4f20_00078: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00078: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00078_78_activation=relu,height=55.6129,width=4.0297_2025-03-18_14-28-35')
# - trainable_e4f20_00079: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00079: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00079_79_activation=tanh,height=48.9382,width=14.5422_2025-03-18_14-28-35')
# - trainable_e4f20_00080: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00080: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00080_80_activation=relu,height=-10.2292,width=17.6859_2025-03-18_14-28-35')
# - trainable_e4f20_00081: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00081: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00081_81_activation=tanh,height=60.4282,width=7.5851_2025-03-18_14-28-35')
# - trainable_e4f20_00082: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00082: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00082_82_activation=relu,height=29.0546,width=3.0313_2025-03-18_14-28-35')
# - trainable_e4f20_00083: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00083: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00083_83_activation=tanh,height=-98.8301,width=16.4679_2025-03-18_14-28-35')
# - trainable_e4f20_00084: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00084: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00084_84_activation=relu,height=40.7674,width=3.0612_2025-03-18_14-28-35')
# - trainable_e4f20_00085: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00085: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00085_85_activation=tanh,height=1.3644,width=8.9024_2025-03-18_14-28-35')
# - trainable_e4f20_00086: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00086: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00086_86_activation=relu,height=-74.1093,width=6.6049_2025-03-18_14-28-35')
# - trainable_e4f20_00087: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00087: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00087_87_activation=tanh,height=-90.1633,width=3.4753_2025-03-18_14-28-35')
# - trainable_e4f20_00088: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00088: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00088_88_activation=relu,height=13.2175,width=16.8051_2025-03-18_14-28-35')
# - trainable_e4f20_00089: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00089: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00089_89_activation=tanh,height=71.1218,width=2.9235_2025-03-18_14-28-35')
# - trainable_e4f20_00090: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00090: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00090_90_activation=relu,height=27.0870,width=13.7854_2025-03-18_14-28-35')
# - trainable_e4f20_00091: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00091: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00091_91_activation=tanh,height=96.2353,width=0.1301_2025-03-18_14-28-35')
# - trainable_e4f20_00092: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00092: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00092_92_activation=relu,height=84.5621,width=18.7143_2025-03-18_14-28-35')
# - trainable_e4f20_00093: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00093: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00093_93_activation=tanh,height=71.9887,width=15.6160_2025-03-18_14-28-35')
# - trainable_e4f20_00094: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00094: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00094_94_activation=relu,height=13.2179,width=15.6949_2025-03-18_14-28-35')
# - trainable_e4f20_00095: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00095: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00095_95_activation=tanh,height=23.4966,width=6.4729_2025-03-18_14-28-35')
# - trainable_e4f20_00096: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00096: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00096_96_activation=relu,height=55.4240,width=19.0830_2025-03-18_14-28-35')
# - trainable_e4f20_00097: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00097: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00097_97_activation=tanh,height=54.7706,width=17.9288_2025-03-18_14-28-35')
# - trainable_e4f20_00098: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00098: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00098_98_activation=relu,height=-24.2413,width=19.3087_2025-03-18_14-28-35')
# - trainable_e4f20_00099: FileNotFoundError('Could not fetch metrics for trainable_e4f20_00099: both result.json and progress.csv were not found at /Users/jaron/ray_results/MLFlow logging experiment/trainable_e4f20_00099_99_activation=tanh,height=-50.0538,width=12.0343_2025-03-18_14-28-35')

# %% [markdown]
# If you head over to your MLFlow tracking server, you should see the experiment and the runs that were logged.
#
# ![Ray Tune experiment in MLflow](imgs/mlflow_raytune_experiment.png)
